# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

train = pd.read_csv('./train.csv', index_col='PassengerId')
test = pd.read_csv('./test.csv', index_col='PassengerId')

df_full = train.append(test)
df_full['Survived'] = df_full['Survived'].astype(pd.Int64Dtype())

print(df_full.dtypes)
df_full.head()
# Out:
# Survived      Int64
# Pclass        int64
# Name         object
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# dtype: object
# /tmp/ipykernel_20178/2948435218.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_full = train.append(test)
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Exploring the data

# %%
pd.crosstab(df_full['Pclass'], df_full['Survived'], normalize='index').round(3)
# Out:
# Survived      0      1
# Pclass
# 1         0.370  0.630
# 2         0.527  0.473
# 3         0.758  0.242

# %%
pd.crosstab(df_full['Sex'], df_full['Survived'], normalize='index').round(3)
# Out:
# Survived      0      1
# Sex
# female    0.258  0.742
# male      0.811  0.189

# %%
pd.crosstab(df_full['Embarked'], df_full['Survived'], normalize='index').round(3)
# Out:
# Survived      0      1
# Embarked
# C         0.446  0.554
# Q         0.610  0.390
# S         0.663  0.337

# %% [markdown]
# ### Adding More Features

# %% [markdown]
# #### Age groups

# %%
#removing for now, breaks pipeline
#bins = [0, 2, 12, 20, 60, np.inf]
#labels = ['baby', 'child', 'teenager', 'adult', 'elderly']
#df_full['AgeGroup'] = pd.cut(train.Age, bins, labels = labels)

# %% [markdown]
# #### Title

# %%
df_full['Title'] = df_full['Name'].str.extract('([A-Za-z]+)\.', expand=False)

# %%
pd.crosstab(df_full['Title'], df_full['Survived'], margins=True, dropna= False).sort_values('All', ascending=False)
# Out:
# Survived    0    1   All
# Title
# All       549  342  1309
# Mr        436   81   757
# Miss       55  127   260
# Mrs        26   99   197
# Master     17   23    61
# Dr          4    3     8
# Rev         6    0     8
# Col         1    1     4
# Major       1    1     2
# Mlle        0    2     2
# Ms          0    1     2
# Don         1    0     1
# Jonkheer    1    0     1
# Lady        0    1     1
# Mme         0    1     1
# Countess    0    1     1
# Sir         0    1     1
# Capt        1    0     1

# %% [markdown]
# By comparing 'All' to what the totals should be, we can see how many of each was nan and belongs to the testing group. We can pick The top groups knowing those categories are represented in both.

# %%
df_full['Title'] = df_full['Title'].replace(
    ['Lady', 'Countess','Capt', 'Col', 'Don', 'Major', 'Sir', 'Jonkheer', 'Dona'],
    'Other')
df_full['Title'] = df_full['Title'].replace(['Mlle', 'Ms'], 'Miss')
df_full['Title'] = df_full['Title'].replace('Mme', 'Mrs')

# %% [markdown]
# #### Deck and room from cabin

# %%
df_full[['Deck', 'Room']] = df_full['Cabin'].str.extract(r'([A-Z])([0-9]+)')
df_full['Room'] = df_full['Room'].astype(pd.StringDtype()).astype('float64')

# %%
df_full.groupby(['Survived'])[['Room']].mean().round(1)
# Out:
#           Room
# Survived
# 0         53.7
# 1         48.9

# %%
df_full.groupby(['Survived', 'Deck'])[['Room']].mean().round(1)
# Out:
#                Room
# Survived Deck
# 0        A     18.4
#          B     57.5
#          C     74.6
#          D     33.1
#          E     53.0
#          F     20.0
#          G     44.2
# 1        A     22.3
#          B     50.1
#          C     76.2
#          D     27.7
#          E     48.8
#          F     15.9
#          G      6.0

# %% [markdown]
# Room appears to only have an effect on survival when combined with deck.

# %%
pd.crosstab(df_full['Deck'], df_full['Survived'], normalize='index').round(3)
# Out:
# Survived      0      1
# Deck
# A         0.533  0.467
# B         0.255  0.745
# C         0.407  0.593
# D         0.233  0.767
# E         0.242  0.758
# F         0.222  0.778
# G         0.714  0.286

# %% [markdown]
# Deck has an effect by itself.

# %% [markdown]
# #### Ticket

# %%
reversed_ticket = pd.DataFrame()
reversed_ticket[['Ticket_num', 'Ticket_ext1', 'Ticket_ext2']] = df_full['Ticket'].str[::-1].str.split(' ', expand=True)

df_full['Ticket_num'] = pd.to_numeric(reversed_ticket['Ticket_num'].str[::-1], 'coerce')
df_full['Ticket_ext'] = reversed_ticket['Ticket_ext1'].str[::-1] #+ reversed_ticket['Ticket_ext2'].str[::-1]

# %% [markdown]
# #### Family size and survival

# %%
df_full['LastName'] = df_full['Name'].str.extract('^([a-zA-Z]+)')

# %%
df_full['FamSize'] = df_full['SibSp'] + df_full['Parch'] + 1
pd.crosstab(df_full['FamSize'], df_full['Survived'], normalize='index').round(3)
# Out:
# Survived      0      1
# FamSize
# 1         0.696  0.304
# 2         0.447  0.553
# 3         0.422  0.578
# 4         0.276  0.724
# 5         0.800  0.200
# 6         0.864  0.136
# 7         0.667  0.333
# 8         1.000  0.000
# 11        1.000  0.000

# %% [markdown]
# The following lines calculate the percentage of family that is known to survive. This is not including the observed person. This should make the validation tests more accurate.

# %%
df_full['FamSurvived'] = (df_full.groupby(['LastName', 'FamSize', 'Cabin'], dropna = False)['Survived'].transform(np.sum) - df_full['Survived'])/(df_full['FamSize'] - 1)
df_full.loc[df_full['Survived'].isna(), 'FamSurvived'] = df_full.groupby(['LastName', 'FamSize', 'Cabin'], dropna = False)['Survived'].transform(np.nanmean)

df_full.loc[df_full['FamSize'] == 1, 'FamSurvived'] = pd.NA

df_full['FamSurvived'] = df_full['FamSurvived'].astype('float64')

# %% [markdown]
# #### Reviewing additions

# %%
pd.DataFrame(df_full.dtypes, columns = ['Type'])
# Out:
#                 Type
# Survived       Int64
# Pclass         int64
# Name          object
# Sex           object
# Age          float64
# SibSp          int64
# Parch          int64
# Ticket        object
# Fare         float64
# Cabin         object
# Embarked      object
# Title         object
# Deck          object
# Room         float64
# Ticket_num   float64
# Ticket_ext    object
# LastName      object
# FamSize        int64
# FamSurvived  float64

# %%
df_full.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked Title  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S    Mr
# 2                1      0          PC 17599  71.2833   C85        C   Mrs
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S  Miss
# 4                1      0            113803  53.1000  C123        S   Mrs
# 5                0      0            373450   8.0500   NaN        S    Mr
#
#             Deck   Room  Ticket_num Ticket_ext   LastName  FamSize  \
# PassengerId
# 1            NaN    NaN     21171.0        A/5     Braund        2
# 2              C   85.0     17599.0         PC    Cumings        2
# 3            NaN    NaN   3101282.0   STON/O2.  Heikkinen        1
# 4              C  123.0    113803.0       None   Futrelle        2
# 5            NaN    NaN    373450.0       None      Allen        1
#
#              FamSurvived
# PassengerId
# 1                    0.0
# 2                    0.0
# 3                    NaN
# 4                    0.0
# 5                    NaN

# %% [markdown]
# ### Creating train, validation, and test sets

# %%
from sklearn.model_selection import train_test_split

test_x = df_full[df_full['Survived'].isna()]
train = df_full[~df_full['Survived'].isna()]

train, valid = train_test_split(train)
train_survived = train['Survived'].astype('int64')
valid_survived = valid['Survived'].astype('int64')

train_x = train.drop(['Survived'], axis=1)
valid_x = valid.drop(['Survived'], axis=1)
test_x = test_x.drop(['Survived'], axis=1)

# %% [markdown]
# ### Creating a model

# %%
import tensorflow as tf
from tensorflow import keras

# %%
def create_nn():
    mod = keras.Sequential([
        keras.layers.Dense(units=2**8, activation=tf.nn.relu),
        keras.layers.Dense(units=2**9, activation=tf.nn.relu),
        keras.layers.Dense(units=2**10, activation=tf.nn.relu),
        keras.layers.Dense(units=2**11, activation=tf.nn.relu),
        keras.layers.Dense(units=2**10, activation=tf.nn.relu),
        keras.layers.Dense(units=2**9, activation=tf.nn.relu),
        keras.layers.Dense(units=2**8, activation=tf.nn.relu),
        keras.layers.Dense(2, activation=tf.nn.softmax)
    ])
    
    mod.compile(
        optimizer=tf.optimizers.Adam(learning_rate=0.001),
        loss=tf.losses.sparse_categorical_crossentropy,
        metrics=['accuracy']
    )
    return mod

# %% [markdown]
# ### Creating a pipeline

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer, SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.feature_extraction import text


categorical_transformer = Pipeline(
    steps=[
        ('imputer', SimpleImputer(strategy='most_frequent')),
        ('onehot', OneHotEncoder(handle_unknown='ignore'))
    ])

pass_transformer = ColumnTransformer(
    remainder='passthrough',
    transformers=[])

transfrom_cols = ColumnTransformer(
    remainder='drop',
    verbose=False,
    sparse_threshold=0,
    transformers=[
        ('categorical transform', categorical_transformer, [
            'Pclass', 'Sex', 'Embarked', 'Deck', 'Title'
            ]),
        ('passthrough columns', pass_transformer, [
            'Age', 'SibSp', 'Parch', 'Fare', 'Room', 'Ticket_num', 'FamSize', 'FamSurvived'
            ])
    ])

it_imputer = IterativeImputer()

preprocessor = Pipeline(
    verbose=False,
    steps = [
        ('transform columns', transfrom_cols),
        ('multivatiate imputer', it_imputer)
    ])

model = create_nn()

# %% [markdown]
# Test preprocessor for array shape

# %%
preprocessor.fit_transform(train_x).shape
# Out:
# (668, 30)

# %%
preprocessor.fit_transform(test_x).shape
# Out:
# (418, 30)

# %%
preprocessor.fit_transform(valid_x).shape
# Out:
# (223, 30)

# %%
model.fit(preprocessor.fit_transform(train_x), train_survived, batch_size = 2, epochs=100)
# Out:
# Epoch 1/100
# 334/334 [==============================] - 1s 2ms/step - loss: 0.6650 - accuracy: 0.6213
# Epoch 2/100
# 334/334 [==============================] - 1s 2ms/step - loss: 0.6633 - accuracy: 0.6213
# Epoch 3/100
# 334/334 [==============================] - 1s 2ms/step - loss: 1.7870 - accuracy: 0.6168
# Epoch 4/100
# 334/334 [==============================] - 1s 2ms/step - loss: 0.6632 - accuracy: 0.6213
# Epoch 5/100
# 334/334 [==============================] - 1s 2ms/step - loss: 0.6630 - accuracy: 0.6213
# Epoch 6/100
# 334/334 [==============================] - 1s 2ms/step - loss: 0.6630 - accuracy: 0.6213
# Epoch 7/100
# 334/334 [==============================] - 1s 2ms/step - loss: 0.6635 - accuracy: 0.6213
# Epoch 8/100
# 334/334 [==============================] - 1s 2ms/step - loss: 0.6630 - accuracy: 0.6213
# Epoch 9/100
# 334/334 [==============================] - 1s 2ms/step - loss: 0.6633 - accuracy: 0.6213
# Epoch 10/100
# 334/334 [==============================] - 1s 2ms/step - loss: 0.6623 - accuracy: 0.6213
# Epoch 11/100
# 334/334 [==============================] - 1s 2ms/step - loss: 0.6631 - accuracy: 0.6213
# Epoch 12/100
# 334/334 [==============================] - 1s 2ms/step - loss: 0.6633 - accuracy: 0.6213
# Epoch 13/100
# 334/334 [==============================] - 1s 2ms/step - loss: 0.6631 - accuracy: 0.6213
# Epoch 14/100
# 334/334 [==============================] - 1s 2ms/step - loss: 0.6632 - accuracy: 0.6213
# Epoch 15/100
# 334/334 [==============================] - 1s 2ms/step - loss: 0.6634 - accuracy: 0.6213
# Epoch 16/100
# 334/334 [==============================] - 1s 2ms/step - loss: 0.6629 - accuracy: 0.6213
# Epoch 17/100
# 334/334 [==============================] - 1s 2ms/step - loss: 0.6630 - accuracy: 0.6213
# Epoch 18/100
# 334/334 [==============================] - 1s 2ms/step - loss: 0.6632 - accuracy: 0.6213
# Epoch 19/100
# 334/334 [==============================] - 1s 2ms/step - loss: 0.6631 - accuracy: 0.6213
# Epoch 20/100
# 334/334 [==============================] - 1s 2ms/step - loss: 0.6633 - accuracy: 0.6213
# Epoch 21/100
# 334/334 [==============================] - 1s 2ms/step - loss: 0.6623 - accuracy: 0.6213
# Epoch 22/100
# 334/334 [==============================] - 1s 2ms/step - loss: 0.6636 - accuracy: 0.6213
# Epoch 23/100
# 334/334 [==============================] - 1s 2ms/step - loss: 0.6629 - accuracy: 0.6213
# Epoch 24/100
# 334/334 [==============================] - 1s 2ms/step - loss: 0.6631 - accuracy: 0.6213
# Epoch 25/100
# 334/334 [==============================] - 1s 2ms/step - loss: 0.6628 - accuracy: 0.6213
# Epoch 26/100
# 334/334 [==============================] - 1s 2ms/step - loss: 0.6629 - accuracy: 0.6213
# Epoch 27/100
# 334/334 [==============================] - 1s 2ms/step - loss: 0.6632 - accuracy: 0.6213
# Epoch 28/100
# 334/334 [==============================] - 1s 2ms/step - loss: 0.6631 - accuracy: 0.6213
# Epoch 29/100
# 334/334 [==============================] - 1s 2ms/step - loss: 0.6634 - accuracy: 0.6213
# Epoch 30/100
# 334/334 [==============================] - 1s 2ms/step - loss: 0.6630 - accuracy: 0.6213
# Epoch 31/100
# 334/334 [==============================] - 1s 2ms/step - loss: 0.6633 - accuracy: 0.6213
# Epoch 32/100
# 334/334 [==============================] - 1s 2ms/step - loss: 0.6632 - accuracy: 0.6213
# Epoch 33/100
# 334/334 [==============================] - 1s 2ms/step - loss: 0.6631 - accuracy: 0.6213
# Epoch 34/100
# 334/334 [==============================] - 1s 2ms/step - loss: 0.6632 - accuracy: 0.6213
# Epoch 35/100
# 334/334 [==============================] - 1s 2ms/step - loss: 0.6628 - accuracy: 0.6213
# Epoch 36/100
# 334/334 [==============================] - 1s 2ms/step - loss: 0.6629 - accuracy: 0.6213
# Epoch 37/100
# 334/334 [==============================] - 1s 2ms/step - loss: 0.6628 - accuracy: 0.6213
# Epoch 38/100
# 334/334 [==============================] - 1s 2ms/step - loss: 0.6632 - accuracy: 0.6213
# Epoch 39/100
#  57/334 [====>.........................] - ETA: 0s - loss: 0.6630 - accuracy: 0.6140
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/alex/workspace/my_repositories/titanic/titanicV2.ipynb Cell 42' in <module>
# ----> <a href='vscode-notebook-cell:/home/alex/workspace/my_repositories/titanic/titanicV2.ipynb#ch0000050?line=0'>1</a> model.fit(preprocessor.fit_transform(train_x), train_survived, batch_size = 2, epochs=100)
#
# File ~/anaconda3/envs/tf/lib/python3.8/site-packages/keras/engine/training.py:1184, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/keras/engine/training.py?line=1176'>1177</a> with tf.profiler.experimental.Trace(
#    <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/keras/engine/training.py?line=1177'>1178</a>     'train',
#    <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/keras/engine/training.py?line=1178'>1179</a>     epoch_num=epoch,
#    <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/keras/engine/training.py?line=1179'>1180</a>     step_num=step,
#    <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/keras/engine/training.py?line=1180'>1181</a>     batch_size=batch_size,
#    <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/keras/engine/training.py?line=1181'>1182</a>     _r=1):
#    <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/keras/engine/training.py?line=1182'>1183</a>   callbacks.on_train_batch_begin(step)
# -> <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/keras/engine/training.py?line=1183'>1184</a>   tmp_logs = self.train_function(iterator)
#    <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/keras/engine/training.py?line=1184'>1185</a>   if data_handler.should_sync:
#    <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/keras/engine/training.py?line=1185'>1186</a>     context.async_wait()
#
# File ~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py:885, in Function.__call__(self, *args, **kwds)
#     <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py?line=881'>882</a> compiler = "xla" if self._jit_compile else "nonXla"
#     <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py?line=883'>884</a> with OptionalXlaContext(self._jit_compile):
# --> <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py?line=884'>885</a>   result = self._call(*args, **kwds)
#     <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py?line=886'>887</a> new_tracing_count = self.experimental_get_tracing_count()
#     <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py?line=887'>888</a> without_tracing = (tracing_count == new_tracing_count)
#
# File ~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py:917, in Function._call(self, *args, **kwds)
#     <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py?line=913'>914</a>   self._lock.release()
#     <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py?line=914'>915</a>   # In this case we have created variables on the first call, so we run the
#     <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py?line=915'>916</a>   # defunned version which is guaranteed to never create variables.
# --> <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py?line=916'>917</a>   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py?line=917'>918</a> elif self._stateful_fn is not None:
#     <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py?line=918'>919</a>   # Release the lock early so that multiple threads can perform the call
#     <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py?line=919'>920</a>   # in parallel.
#     <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py?line=920'>921</a>   self._lock.release()
#
# File ~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/function.py:3038, in Function.__call__(self, *args, **kwargs)
#    <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=3034'>3035</a> """Calls a graph function specialized to the inputs."""
#    <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=3035'>3036</a> with self._lock:
#    <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=3036'>3037</a>   (graph_function,
# -> <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=3037'>3038</a>    filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=3038'>3039</a> return graph_function._call_flat(
#    <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=3039'>3040</a>     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/function.py:3421, in Function._maybe_define_function(self, args, kwargs)
#    <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=3417'>3418</a>   flat_args, filtered_flat_args = [None], []
#    <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=3419'>3420</a> cache_key_context = self._cache_key_context()
# -> <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=3420'>3421</a> cache_key = self._cache_key(args, kwargs, cache_key_context)
#    <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=3422'>3423</a> try:
#    <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=3423'>3424</a>   hash(cache_key)
#
# File ~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/function.py:3202, in Function._cache_key(self, args, kwargs, cache_key_context, include_tensor_ranks_only)
#    <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=3198'>3199</a>   inputs = (args, kwargs)
#    <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=3199'>3200</a>   input_signature = pywrap_tfe.TFE_Py_EncodeArg(inputs,
#    <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=3200'>3201</a>                                                 include_tensor_ranks_only)
# -> <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=3201'>3202</a>   hashable_input_signature = _make_input_signature_hashable(input_signature)
#    <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=3202'>3203</a> else:
#    <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=3203'>3204</a>   del args, kwargs
#
# File ~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/function.py:114, in _make_input_signature_hashable(elem)
#     <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=101'>102</a> """Rewrite input signature to be hashable.
#     <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=102'>103</a>
#     <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=103'>104</a> We replace nested variables in the input signature with TensorSpec in order to
#    (...)
#     <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=110'>111</a>   A hashable object for the requested input signature
#     <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=111'>112</a> """
#     <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=112'>113</a> try:
# --> <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=113'>114</a>   hash(elem)
#     <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=114'>115</a> except TypeError:
#     <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=115'>116</a>   # TODO(slebedev): consider using nest.
#     <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=116'>117</a>   if isinstance(elem, tuple):
#
# File ~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/framework/type_spec.py:329, in TypeSpec.__hash__(self)
#     <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/framework/type_spec.py?line=327'>328</a> def __hash__(self):
# --> <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/framework/type_spec.py?line=328'>329</a>   return hash(self.__get_cmp_key())
#
# File ~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/framework/type_spec.py:367, in TypeSpec.__get_cmp_key(self)
#     <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/framework/type_spec.py?line=364'>365</a> """Returns a hashable eq-comparable key for `self`."""
#     <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/framework/type_spec.py?line=365'>366</a> # TODO(b/133606651): Decide whether to cache this value.
# --> <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/framework/type_spec.py?line=366'>367</a> return (type(self), self.__make_cmp_key(self._serialize()))
#
# File ~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/framework/type_spec.py:371, in TypeSpec.__make_cmp_key(self, value)
#     <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/framework/type_spec.py?line=368'>369</a> def __make_cmp_key(self, value):
#     <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/framework/type_spec.py?line=369'>370</a>   """Converts `value` to a hashable key."""
# --> <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/framework/type_spec.py?line=370'>371</a>   if isinstance(value,
#     <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/framework/type_spec.py?line=371'>372</a>                 (int, float, bool, np.generic, dtypes.DType, TypeSpec)):
#     <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/framework/type_spec.py?line=372'>373</a>     return value
#     <a href='file:///~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/framework/type_spec.py?line=373'>374</a>   if isinstance(value, compat.bytes_or_text_types):
#
# File ~/anaconda3/envs/tf/lib/python3.8/abc.py:96, in ABCMeta.__instancecheck__(cls, instance)
#      <a href='file:///~/anaconda3/envs/tf/lib/python3.8/abc.py?line=89'>90</a>     """Register a virtual subclass of an ABC.
#      <a href='file:///~/anaconda3/envs/tf/lib/python3.8/abc.py?line=90'>91</a>
#      <a href='file:///~/anaconda3/envs/tf/lib/python3.8/abc.py?line=91'>92</a>     Returns the subclass, to allow usage as a class decorator.
#      <a href='file:///~/anaconda3/envs/tf/lib/python3.8/abc.py?line=92'>93</a>     """
#      <a href='file:///~/anaconda3/envs/tf/lib/python3.8/abc.py?line=93'>94</a>     return _abc_register(cls, subclass)
# ---> <a href='file:///~/anaconda3/envs/tf/lib/python3.8/abc.py?line=95'>96</a> def __instancecheck__(cls, instance):
#      <a href='file:///~/anaconda3/envs/tf/lib/python3.8/abc.py?line=96'>97</a>     """Override for isinstance(instance, cls)."""
#      <a href='file:///~/anaconda3/envs/tf/lib/python3.8/abc.py?line=97'>98</a>     return _abc_instancecheck(cls, instance)
#
# KeyboardInterrupt:
